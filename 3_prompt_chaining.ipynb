# %%
from langgraph.graph import StateGraph, START, END
from langchain_ollama import ChatOllama
from typing import TypedDict

# %%
model = ChatOllama(
    model="llama3",
    temperature=0,
)

# %%
class BlogState(TypedDict):

    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state)
# Out:
# {'title': 'Rise of AI in India', 'outline': 'Here is a detailed outline for a blog on the topic "Rise of AI in India":\n\n**I. Introduction**\n\n* Brief overview of Artificial Intelligence (AI) and its growing importance globally\n* Importance of India as a key player in the global AI landscape\n* Thesis statement: The rise of AI in India is transforming industries, creating new opportunities, and driving economic growth.\n\n**II. Current State of AI in India**\n\n* Overview of the current state of AI adoption in India (e.g., government initiatives, private sector investments)\n* Statistics on the growth of AI in India (e.g., number of startups, funding, job creation)\n* Examples of successful AI applications in India (e.g., healthcare, finance, education)\n\n**III. Industries Impacted by AI in India**\n\n* Healthcare: AI-powered diagnostic tools, personalized medicine, and telemedicine\n\t+ Examples: AI-based cancer diagnosis, AI-powered insulin pumps\n* Finance: AI-driven banking, investment analysis, and risk management\n\t+ Examples: AI-powered trading platforms, AI-driven credit scoring\n* Education: AI-powered learning platforms, adaptive testing, and personalized education\n\t+ Examples: AI-powered tutoring systems, AI-driven educational games\n\n**IV. Emerging Trends in AI in India**\n\n* Edge AI: AI processing at the edge of networks, reducing latency and improving real-time decision-making\n* Explainable AI (XAI): AI transparency and interpretability, ensuring trust and accountability\n* Human-AI Collaboration: AI augmenting human capabilities, rather than replacing them\n\n**V. Challenges and Opportunities in AI Adoption in India**\n\n* Data quality and availability: Limited data sets, biased datasets, and data privacy concerns\n* Talent gap: Lack of skilled professionals in AI development, deployment, and maintenance\n* Regulatory framework: Need for clear guidelines on AI ethics, privacy, and security\n\n**VI. Government Initiatives and Support for AI in India**\n\n* National Policy on AI (2018): Encouraging AI adoption, research, and innovation\n* AI-focused initiatives: Startup accelerators, incubators, and funding programs\n* Collaboration with international organizations: International cooperation on AI development and deployment\n\n**VII. Conclusion**\n\n* Recap of the rise of AI in India and its transformative impact on industries\n* Call to action: Encouragement for readers to explore AI opportunities and challenges in India.\n\nThis outline should provide a comprehensive framework for your blog post on the rise of AI in India. Good luck with your writing!', 'content': '**Rise of AI in India: Transforming Industries, Creating New Opportunities, and Driving Economic Growth**\n\nAs Artificial Intelligence (AI) continues to revolutionize industries globally, India is emerging as a key player in the AI landscape. With its large pool of skilled professionals, growing startup ecosystem, and government support, India is poised to become a significant hub for AI innovation and adoption.\n\n**Current State of AI in India**\n\nIndia has made significant progress in AI adoption, with various government initiatives and private sector investments driving growth. According to a report by MarketsandMarkets, the Indian AI market size is expected to grow from USD 1.5 billion in 2020 to USD 4.8 billion by 2025, at a Compound Annual Growth Rate (CAGR) of 24.3%. This growth is driven by increasing adoption across industries such as healthcare, finance, and education.\n\nSome notable examples of successful AI applications in India include:\n\n* Healthcare: AI-powered diagnostic tools have improved cancer diagnosis accuracy to over 90%, while AI-powered insulin pumps have enabled real-time monitoring and adjustment.\n* Finance: AI-driven banking platforms have enhanced customer experience, while AI-powered trading platforms have optimized investment decisions.\n* Education: AI-powered learning platforms have personalized educati ...

# %%
print(final_state['outline'])
# Out:
# Here is a detailed outline for a blog on the topic "Rise of AI in India":
#
# **I. Introduction**
#
# * Brief overview of Artificial Intelligence (AI) and its growing importance globally
# * Importance of India as a key player in the global AI landscape
# * Thesis statement: The rise of AI in India is transforming industries, creating new opportunities, and driving economic growth.
#
# **II. Current State of AI in India**
#
# * Overview of the current state of AI adoption in India (e.g., government initiatives, private sector investments)
# * Statistics on the growth of AI in India (e.g., number of startups, funding, job creation)
# * Examples of successful AI applications in India (e.g., healthcare, finance, education)
#
# **III. Industries Impacted by AI in India**
#
# * Healthcare: AI-powered diagnostic tools, personalized medicine, and telemedicine
# 	+ Examples: AI-based cancer diagnosis, AI-powered insulin pumps
# * Finance: AI-driven banking, investment analysis, and risk management
# 	+ Examples: AI-powered trading platforms, AI-driven credit scoring
# * Education: AI-powered learning platforms, adaptive testing, and personalized education
# 	+ Examples: AI-powered tutoring systems, AI-driven educational games
#
# **IV. Emerging Trends in AI in India**
#
# * Edge AI: AI processing at the edge of networks, reducing latency and improving real-time decision-making
# * Explainable AI (XAI): AI transparency and interpretability, ensuring trust and accountability
# * Human-AI Collaboration: AI augmenting human capabilities, rather than replacing them
#
# **V. Challenges and Opportunities in AI Adoption in India**
#
# * Data quality and availability: Limited data sets, biased datasets, and data privacy concerns
# * Talent gap: Lack of skilled professionals in AI development, deployment, and maintenance
# * Regulatory framework: Need for clear guidelines on AI ethics, privacy, and security
#
# **VI. Government Initiatives and Support for AI in India**
#
# * National Policy on AI (2018): Encouraging AI adoption, research, and innovation
# * AI-focused initiatives: Startup accelerators, incubators, and funding programs
# * Collaboration with international organizations: International cooperation on AI development and deployment
#
# **VII. Conclusion**
#
# * Recap of the rise of AI in India and its transformative impact on industries
# * Call to action: Encouragement for readers to explore AI opportunities and challenges in India.
#
# This outline should provide a comprehensive framework for your blog post on the rise of AI in India. Good luck with your writing!

# %%
print(final_state['content'])
# Out:
# **Rise of AI in India: Transforming Industries, Creating New Opportunities, and Driving Economic Growth**
#
# As Artificial Intelligence (AI) continues to revolutionize industries globally, India is emerging as a key player in the AI landscape. With its large pool of skilled professionals, growing startup ecosystem, and government support, India is poised to become a significant hub for AI innovation and adoption.
#
# **Current State of AI in India**
#
# India has made significant progress in AI adoption, with various government initiatives and private sector investments driving growth. According to a report by MarketsandMarkets, the Indian AI market size is expected to grow from USD 1.5 billion in 2020 to USD 4.8 billion by 2025, at a Compound Annual Growth Rate (CAGR) of 24.3%. This growth is driven by increasing adoption across industries such as healthcare, finance, and education.
#
# Some notable examples of successful AI applications in India include:
#
# * Healthcare: AI-powered diagnostic tools have improved cancer diagnosis accuracy to over 90%, while AI-powered insulin pumps have enabled real-time monitoring and adjustment.
# * Finance: AI-driven banking platforms have enhanced customer experience, while AI-powered trading platforms have optimized investment decisions.
# * Education: AI-powered learning platforms have personalized education for students, while AI-driven educational games have improved learning outcomes.
#
# **Industries Impacted by AI in India**
#
# AI is transforming various industries in India, including:
#
# * **Healthcare**: AI-powered diagnostic tools are improving disease diagnosis and treatment. For instance, AI-based cancer diagnosis has increased accuracy to over 90%. AI-powered insulin pumps are enabling real-time monitoring and adjustment.
# * **Finance**: AI-driven banking platforms are enhancing customer experience, while AI-powered trading platforms are optimizing investment decisions. AI-driven credit scoring is reducing loan defaults and improving financial inclusion.
# * **Education**: AI-powered learning platforms are personalizing education for students, while AI-driven educational games are improving learning outcomes.
#
# **Emerging Trends in AI in India**
#
# India is witnessing the emergence of new trends in AI, including:
#
# * **Edge AI**: AI processing at the edge of networks is reducing latency and improving real-time decision-making.
# * **Explainable AI (XAI)**: AI transparency and interpretability are ensuring trust and accountability.
# * **Human-AI Collaboration**: AI is augmenting human capabilities, rather than replacing them.
#
# **Challenges and Opportunities in AI Adoption in India**
#
# Despite the growth of AI in India, there are challenges that need to be addressed:
#
# * **Data quality and availability**: Limited data sets, biased datasets, and data privacy concerns are hindering AI adoption.
# * **Talent gap**: The lack of skilled professionals in AI development, deployment, and maintenance is a significant challenge.
# * **Regulatory framework**: A clear regulatory framework is needed to ensure AI ethics, privacy, and security.
#
# **Government Initiatives and Support for AI in India**
#
# The Indian government has launched several initiatives to support AI adoption and innovation:
#
# * **National Policy on AI (2018)**: The policy aims to encourage AI adoption, research, and innovation.
# * **AI-focused initiatives**: Startup accelerators, incubators, and funding programs are supporting AI startups.
# * **Collaboration with international organizations**: India is collaborating with international organizations to develop and deploy AI solutions.
#
# **Conclusion**
#
# The rise of AI in India is transforming industries, creating new opportunities, and driving economic growth. As the Indian AI market continues to grow, it is essential to address challenges such as data quality, talent gap, and regulatory framework. With government support and private sector investments, India is poised to become a significant hub for AI innovation and adoption.
#
# **Call to Action**
#
# As AI continues to revolutionize industries in India, we encourage readers to explore the opportunities and challenges presented by this technology. Whether you are an entrepreneur, investor, or simply interested in AI, there has never been a better time to be involved in the Indian AI ecosystem.
